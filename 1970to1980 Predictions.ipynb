# %%
import pandas as pd
import numpy as np

# %%
#Read in Dataframe
df = pd.read_csv("temperature_and_ghg_concentrations_1880-2014.csv")

# %%
#Drop index columns
mol = df.drop(["Year", "GCAG", "GISTEMP", "Average Land Temperature (Degrees Celcius)"], axis=1, index=None, columns=None, level=None, inplace=False, errors='raise')

# %%
#Identify columns to loop through
columns = mol.columns

# %%
#This is where we change the base year 
#NOTE 89 base year = 1969 always add two/subtract two to reference excel sheet
base_year_1950 = 70

#Do not touch, loops through to find the slope of the line and the first and last values
#We use point slope formula to determine the slope:  m = (y2-y1)/(x2-x1)
m_array_1880to1950 = []
last_value_array_1950 = []
for i in columns:
    r=0
    for row in mol[i]:
        if row == 0:
            r+=1
            next
        else:
            indx1 = r
            first_value = row
            first_point = [indx1,first_value]
            #print(first_point)  
            break
    last_value_1950 = (mol[i].loc[base_year_1950])
    indx2_1950 = base_year_1950
    last_point_1950 = [indx2_1950,last_value_1950]
    last_value_array_1950.append(last_value_1950)
    
    rise_1950 = (last_value_1950 - first_value)
    run_1950 = (indx2_1950 - indx1)
    m_1950 = rise_1950/run_1950
    m_array_1880to1950.append(m_1950)
    next

# %%
#-------------------Finding slope for 1950 to 1970---------------"THE GREAT ACCELERATION"

#This is where we change the base year 
#NOTE 89 base year = 1969 always add two/subtract two to reference excel sheet
base_year_1970 = 90
first_year_1950 = 70

#Do not touch, loops through to find the slope of the line and the first and last values
#We use point slope formula to determine the slope:  m = (y2-y1)/(x2-x1)
m_array_1950to1970 = []
last_value_array_1970 = []
first_value_array_1950 = []
for i in columns:
    #First Value 1950
    first_value_1950 = (mol[i].loc[first_year_1950])
    indx1_1950 = first_year_1950
    first_point_1950 = [indx1_1950,first_value_1950]
    first_value_array_1950.append(first_value_1950)
    #Last Value 1970
    last_value_1970 = (mol[i].loc[base_year_1970])
    indx2_1970 = base_year_1970
    last_point_1970 = [indx2_1970,last_value_1970]
    last_value_array_1970.append(last_value_1970)
    #Slope for 1950 to 1970
    rise_1950to1970 = (last_value_1970 - first_value_1950)
    run_1950to1970 = (indx2_1970 - indx1_1950)
    m_1950to1970 = rise_1950to1970/run_1950to1970
    m_array_1950to1970.append(m_1950to1970)
    next

# %%
#-------------------Finding slope for 1970 to 1988---------------"Enviromental Agencies creation; first reports of global warming"

#This is where we change the base year 
#NOTE 89 base year = 1969 always add two/subtract two to reference excel sheet
base_year_1970 = 90
last_year_1988 = 108

#Do not touch, loops through to find the slope of the line and the first and last values
#We use point slope formula to determine the slope:  m = (y2-y1)/(x2-x1)
m_array_1970to1988 = []
first_value_array_1970 = []
last_value_array_1988 = []
for i in columns:
    #First Value 1970
    first_value_1970 = (mol[i].loc[base_year_1970])
    indx1_1970 = base_year_1970
    first_point_1970 = [indx1_1970,first_value_1970]
    first_value_array_1970.append(first_value_1970)
    #Last Value 1988
    last_value_1988 = (mol[i].loc[last_year_1988])
    indx2_1988 = last_year_1988
    last_point_1988 = [indx2_1988,last_value_1988]
    last_value_array_1988.append(last_value_1988)
    #Slope for 1970 to 1988
    rise_1970to1988 = (last_value_1988 - first_value_1970)
    run_1970to1988 = (indx2_1988 - indx1_1970)
    m_1970to1988 = rise_1970to1988/run_1970to1988
    m_array_1970to1988.append(m_1970to1988)
    next

# %%
#-------------------Finding slope for 1988to2014 ---------------"Chernobyl in 88; human induced global warming becomes mainstream"

#This is where we change the base year 
#NOTE 89 base year = 1969 always add two/subtract two to reference excel sheet
last_year_2014 = 134
base_year_1988 = 108

#Do not touch, loops through to find the slope of the line and the first and last values
#We use point slope formula to determine the slope:  m = (y2-y1)/(x2-x1)
m_array_1988to2014 = []
first_value_array_1988 = []
last_value_array_2014 = []
for i in columns:
    #First Value 1988
    first_value_1988 = (mol[i].loc[base_year_1988])
    indx1_1988 = base_year_1988
    first_point_1988 = [indx1_1988,first_value_1988]
    first_value_array_1988.append(first_value_1988)
    #Last Value 2014
    last_value_2014 = (mol[i].loc[last_year_2014])
    indx2_2014 = last_year_2014
    last_point_1988 = [indx2_2014,last_value_2014]
    last_value_array_2014.append(last_value_2014)
    #Slope for 1988to2014
    rise_1988to2014 = (last_value_2014 - first_value_1988)
    run_1988to2014 = (indx2_2014 - indx1_1988)
    m_1988to2014 = rise_1988to2014/run_1988to2014
    m_array_1988to2014.append(m_1988to2014)
    next

# %%
#-------------------Finding slope for 2009to2014 ---------------"Most Recent Slope"

#This is where we change the base year 
#NOTE 89 base year = 1969 always add two/subtract two to reference excel sheet
last_year_2014 = 134
base_year_2009 = 129

#Do not touch, loops through to find the slope of the line and the first and last values
#We use point slope formula to determine the slope:  m = (y2-y1)/(x2-x1)
m_array_2009to2014 = []
first_value_array_2009 = []
last_value_array_2014 = []
for i in columns:
    #First Value 2009
    first_value_2009 = (mol[i].loc[base_year_2009])
    indx1_2009 = base_year_2009
    first_point_2009 = [indx1_2009,first_value_2009]
    first_value_array_2009.append(first_value_2009)
    #Last Value 2014
    last_value_2014 = (mol[i].loc[last_year_2014])
    indx2_2014 = last_year_2014
    last_point_2014 = [indx2_2014,last_value_2014]
    last_value_array_2014.append(last_value_2014)
    #Slope for 2009to2014
    rise_2009to2014 = (last_value_2014 - first_value_2009)
    run_2009to2014 = (indx2_2014 - indx1_2009)
    m_2009to2014 = rise_2009to2014/run_2009to2014
    m_array_2009to2014.append(m_2009to2014)
    next

# %%
#Here I am finding the actual values for the years 1970 through 1980
#---------------------------------------------------------------------#

base_year_1971 = 91
base_year_1972 = 92
base_year_1973 = 93
base_year_1974 = 94
base_year_1975 = 95
base_year_1976 = 96
base_year_1977 = 97
base_year_1978 = 98
base_year_1979 = 99
base_year_1980 = 100

actual_values_array_1971 = []
actual_values_array_1972 = []
actual_values_array_1973 = []
actual_values_array_1974 = []
actual_values_array_1975 = []
actual_values_array_1976 = []
actual_values_array_1977 = []
actual_values_array_1978 = []
actual_values_array_1979 = []
actual_values_array_1980 = []

for i in columns:
    #Values for 1971
    actual_values_1971 = (mol[i].iloc[base_year_1971])
    actual_values_array_1971.append(actual_values_1971)
    #Values for 1972
    actual_values_1972 = (mol[i].loc[base_year_1972])
    actual_values_array_1972.append(actual_values_1972)
    #Values for 1973
    actual_values_1973 = (mol[i].loc[base_year_1973])
    actual_values_array_1973.append(actual_values_1973)
    #Values for 1974
    actual_values_1974 = (mol[i].loc[base_year_1974])
    actual_values_array_1974.append(actual_values_1974)
    #Values for 1975
    actual_values_1975 = (mol[i].loc[base_year_1975])
    actual_values_array_1975.append(actual_values_1975)
    #Values for 1976
    actual_values_1976 = (mol[i].loc[base_year_1976])
    actual_values_array_1976.append(actual_values_1976)
    #Values for 1977
    actual_values_1977 = (mol[i].loc[base_year_1977])
    actual_values_array_1977.append(actual_values_1977)
    #Values for 1978
    actual_values_1978 = (mol[i].loc[base_year_1978])
    actual_values_array_1978.append(actual_values_1978)
    #Values for 1979
    actual_values_1979 = (mol[i].loc[base_year_1979])
    actual_values_array_1979.append(actual_values_1979)
    #Values for 1980
    actual_values_1980 = (mol[i].loc[base_year_1980])
    actual_values_array_1980.append(actual_values_1980)

# %%
#Here we are assigning and using yearly intervals * our slope to get an accurate prediction based on however many
#Years we are looking forward to. For example, if we are looking for 5 years in the future, we would use a 5 year interval
#NOTE the longer the interval the more inaccurate the data gets
#------------------------------------------------------------------------------------------------------------------------#

#This is where we change the interval
year_interval = 1
year_interval_2 = 2
year_interval_3 = 3
year_interval_4 = 4
year_interval_5 = 5
year_interval_6 = 6
year_interval_7 = 7
year_interval_8 = 8
year_interval_9 = 9
year_interval_10 = 10

#Predicted concentration change using the slope from 1950 to 1970
predict_concentration_change_1950to1970 = [i* year_interval for i in m_array_1950to1970]

#Predicted concentration change using slope from 1970 to 1988
predict_concentration_change_1970to1988 = [i* year_interval for i in m_array_1970to1988]

#Predicted concentration change using slope from 1988 to 2014
predict_concentration_change_1988to2014 = [i* year_interval for i in m_array_1988to2014]

#Predicted concentration change using slope from 2009 to 2014
predict_concentration_change_2009to2014 = [i* year_interval for i in m_array_2009to2014]

#Here I am using the base slope of 1950 to 1970 ("The Great Acceleration") to get every predictions between 1970 through 1980
#---------------------------------------------------------------------------------------------------------------------------#

##Predicted concentration change using slope from 1950 to 1970 for 1971
predict_concentration_change_1950to1970_1971 = [i* year_interval for i in m_array_1950to1970]

#Predicted concentration change using slope from 1950 to 1970 for 1972
predict_concentration_change_1950to1970_1972 = [i* year_interval_2 for i in m_array_1950to1970]

#Predicted concentration change using slope from 1950 to 1970 for 1973
predict_concentration_change_1950to1970_1973 = [i* year_interval_2 for i in m_array_1950to1970]

#Predicted concentration change using slope from 1950 to 1970 for 1974
predict_concentration_change_1950to1970_1974 = [i* year_interval_3 for i in m_array_1950to1970]

#Predicted concentration change using slope from 1950 to 1970 for 1975
predict_concentration_change_1950to1970_1975 = [i* year_interval_4 for i in m_array_1950to1970]

#Predicted concentration change using slope from 1950 to 1970 for 1976
predict_concentration_change_1950to1970_1976 = [i* year_interval_5 for i in m_array_1950to1970]

#Predicted concentration change using slope from 1950 to 1970 for 1977
predict_concentration_change_1950to1970_1977 = [i* year_interval_6 for i in m_array_1950to1970]

#Predicted concentration change using slope from 1950 to 1970 for 1978
predict_concentration_change_1950to1970_1978 = [i* year_interval_7 for i in m_array_1950to1970]

#Predicted concentration change using slope from 1950 to 1970 for 1979
predict_concentration_change_1950to1970_1979 = [i* year_interval_8 for i in m_array_1950to1970]

#Predicted concentration change using slope from 1950 to 1970 for 1980
predict_concentration_change_1950to1970_1980 = [i* year_interval_9 for i in m_array_1950to1970]

#Here I am using the base slope of 1970 to 1988 to get every predictions between 1970 through 1980
#---------------------------------------------------------------------------------------------------------------------------#

##Predicted concentration change using slope from 1970 to 1988 for 1971
predict_concentration_change_1970to1988_1971 = [i* year_interval for i in m_array_1970to1988]

#Predicted concentration change using slope from 1950 to 1970 for 1972
predict_concentration_change_1970to1988_1972 = [i* year_interval_2 for i in m_array_1970to1988]

#Predicted concentration change using slope from 1950 to 1970 for 1973
predict_concentration_change_1970to1988_1973 = [i* year_interval_2 for i in m_array_1970to1988]

#Predicted concentration change using slope from 1950 to 1970 for 1974
predict_concentration_change_1970to1988_1974 = [i* year_interval_3 for i in m_array_1970to1988]

#Predicted concentration change using slope from 1950 to 1970 for 1975
predict_concentration_change_1970to1988_1975 = [i* year_interval_4 for i in m_array_1970to1988]

#Predicted concentration change using slope from 1950 to 1970 for 1976
predict_concentration_change_1970to1988_1976 = [i* year_interval_5 for i in m_array_1970to1988]

#Predicted concentration change using slope from 1950 to 1970 for 1977
predict_concentration_change_1970to1988_1977 = [i* year_interval_6 for i in m_array_1970to1988]

#Predicted concentration change using slope from 1950 to 1970 for 1978
predict_concentration_change_1970to1988_1978 = [i* year_interval_7 for i in m_array_1970to1988]

#Predicted concentration change using slope from 1950 to 1970 for 1979
predict_concentration_change_1970to1988_1979 = [i* year_interval_8 for i in m_array_1970to1988]

#Predicted concentration change using slope from 1950 to 1970 for 1980
predict_concentration_change_1970to1988_1980 = [i* year_interval_9 for i in m_array_1970to1988]




#Here I am using the base slope of 1988 to 2014 to get every predictions between 1970 through 1980
#---------------------------------------------------------------------------------------------------------------------------#

##Predicted concentration change using slope from 1988 to 2014 for 1971
predict_concentration_change_1988to2014_1971 = [i* year_interval for i in m_array_1988to2014]

#Predicted concentration change using slope from 1988 to 2014 for 1972
predict_concentration_change_1988to2014_1972 = [i* year_interval_2 for i in m_array_1988to2014]

#Predicted concentration change using slope from 1988 to 2014 for 1973
predict_concentration_change_1988to2014_1973 = [i* year_interval_2 for i in m_array_1988to2014]

#Predicted concentration change using slope from 1988 to 2014 for 1974
predict_concentration_change_1988to2014_1974 = [i* year_interval_3 for i in m_array_1988to2014]

#Predicted concentration change using slope from 1988 to 2014 for 1975
predict_concentration_change_1988to2014_1975 = [i* year_interval_4 for i in m_array_1988to2014]

#Predicted concentration change using slope from 1988 to 2014 for 1976
predict_concentration_change_1988to2014_1976 = [i* year_interval_5 for i in m_array_1988to2014]

#Predicted concentration change using slope from 1988 to 2014 for 1977
predict_concentration_change_1988to2014_1977 = [i* year_interval_6 for i in m_array_1988to2014]

#Predicted concentration change using slope from 1988 to 2014 for 1978
predict_concentration_change_1988to2014_1978 = [i* year_interval_7 for i in m_array_1988to2014]

#Predicted concentration change using slope from 1988 to 2014 for 1979
predict_concentration_change_1988to2014_1979 = [i* year_interval_8 for i in m_array_1988to2014]

#Predicted concentration change using slope from 1988 to 2014 for 1980
predict_concentration_change_1988to2014_1980 = [i* year_interval_9 for i in m_array_1988to2014]

# %%
#Here we are assigning back into DataFrame format, as well as doing our calculations
#We are multiplying our slope given from our picked years to the value of the year we are predicting
#---------------------------------------------------------------------------------------------------#

#DataFrame for 1950 to 1970 predictions
target_predict = [last_value_array_1970]
df1_1970actual = pd.DataFrame(last_value_array_1970)
df2_predicted = pd.DataFrame(predict_concentration_change_1950to1970)
final_df_1950to1970 = df1_1970actual + df2_predicted
predicted_1950to1970 = final_df_1950to1970.set_index(columns)

#DataFrame for 1970 to 1988 predictions
df1_1970actual = pd.DataFrame(last_value_array_1970)
df2_predicted_1970to1988 = pd.DataFrame(predict_concentration_change_1970to1988)
final_df_1970to1988 = df1_1970actual + df2_predicted_1970to1988
predicted_1970to1988 = final_df_1970to1988.set_index(columns)

#DataFrame for 1988to2014 predictions
df1_1970actual = pd.DataFrame(last_value_array_1970)
df2_predicted_1988to2014 = pd.DataFrame(predict_concentration_change_1988to2014)
final_df_1988to2014 = df1_1970actual + df2_predicted_1988to2014
predicted_1988to2014 = final_df_1988to2014.set_index(columns)

#DataFrame for 2009to2014 predictions
df1_1970actual = pd.DataFrame(last_value_array_1970)
df2_predicted_2009to2014 = pd.DataFrame(predict_concentration_change_2009to2014)
final_df_2009to2014 = df1_1970actual + df2_predicted_2009to2014
predicted_2009to2014 = final_df_2009to2014.set_index(columns)

#Here I am using the base slope of 1950 to 1970 ("The Great Acceleration") to get every predictions between 1970 through 1980
#NOTE that to get the prediction for the next year you must multiply the slope from the PREVIOUS year
#---------------------------------------------------------------------------------------------------------------------------#

#1971
df1_1970actual = pd.DataFrame(last_value_array_1970)
df2_predicted_1971 = pd.DataFrame(predict_concentration_change_1950to1970_1971)
final_df_1950to1970_1971 = df1_1970actual + df2_predicted_1971
predicted_1950to1970_1971 = final_df_1950to1970_1971.set_index(columns)

#1972
df1_1971actual = pd.DataFrame(actual_values_array_1971)
df2_predicted_1972 = pd.DataFrame(predict_concentration_change_1950to1970_1972)
final_df_1950to1970_1972 = df1_1971actual + df2_predicted_1972
predicted_1950to1970_1972 = final_df_1950to1970_1972.set_index(columns)

#1973
df1_1972actual = pd.DataFrame(actual_values_array_1972)
df2_predicted_1973 = pd.DataFrame(predict_concentration_change_1950to1970_1973)
final_df_1950to1970_1973 = df1_1972actual + df2_predicted_1973
predicted_1950to1970_1973 = final_df_1950to1970_1973.set_index(columns)

#1974
df1_1973actual = pd.DataFrame(actual_values_array_1973)
df2_predicted_1974 = pd.DataFrame(predict_concentration_change_1950to1970_1974)
final_df_1950to1970_1974 = df1_1973actual + df2_predicted_1974
predicted_1950to1970_1974 = final_df_1950to1970_1974.set_index(columns)

#1975
df1_1974actual = pd.DataFrame(actual_values_array_1974)
df2_predicted_1975 = pd.DataFrame(predict_concentration_change_1950to1970_1975)
final_df_1950to1970_1975 = df1_1974actual + df2_predicted_1975
predicted_1950to1970_1975 = final_df_1950to1970_1975.set_index(columns)

#1976
df1_1975actual = pd.DataFrame(actual_values_array_1975)
df2_predicted_1976 = pd.DataFrame(predict_concentration_change_1950to1970_1976)
final_df_1950to1970_1976 = df1_1975actual + df2_predicted_1976
predicted_1950to1970_1976 = final_df_1950to1970_1976.set_index(columns)

#1977
df1_1976actual = pd.DataFrame(actual_values_array_1976)
df2_predicted_1977 = pd.DataFrame(predict_concentration_change_1950to1970_1977)
final_df_1950to1970_1977 = df1_1976actual + df2_predicted_1977
predicted_1950to1970_1977 = final_df_1950to1970_1977.set_index(columns)

#1978
df1_1977actual = pd.DataFrame(actual_values_array_1977)
df2_predicted_1978 = pd.DataFrame(predict_concentration_change_1950to1970_1978)
final_df_1950to1970_1978 = df1_1977actual + df2_predicted_1978
predicted_1950to1970_1978 = final_df_1950to1970_1978.set_index(columns)

#1979
df1_1978actual = pd.DataFrame(actual_values_array_1978)
df2_predicted_1979 = pd.DataFrame(predict_concentration_change_1950to1970_1979)
final_df_1950to1970_1979 = df1_1978actual + df2_predicted_1979
predicted_1950to1970_1979 = final_df_1950to1970_1979.set_index(columns)

#1980
df1_1979actual = pd.DataFrame(actual_values_array_1979)
df2_predicted_1980 = pd.DataFrame(predict_concentration_change_1950to1970_1980)
final_df_1950to1970_19 = df1_1979actual + df2_predicted_1980
predicted_1950to1970_1974 = final_df_1950to1970_1974.set_index(columns)

#Here I am using the base slope of 1970 to 1988 to get every predictions between 1970 through 1980
#NOTE that to get the prediction for the next year you must multiply the slope from the PREVIOUS year
#---------------------------------------------------------------------------------------------------------------------------#

#1971
df1_1970actual = pd.DataFrame(last_value_array_1970)
df2_predicted_1971_1970to1988slope = pd.DataFrame(predict_concentration_change_1970to1988_1971)
final_df_1970to1988_1971 = df1_1970actual + df2_predicted_1971_1970to1988slope
predicted_1970to1988_1971 = final_df_1950to1970_1971.set_index(columns)

#1972
df1_1971actual = pd.DataFrame(actual_values_array_1971)
df2_predicted_1972_1970to1988slope = pd.DataFrame(predict_concentration_change_1970to1988_1972)
final_df_1970to1988_1972 = df1_1971actual + df2_predicted_1972_1970to1988slope
predicted_1970to1988_1972 = final_df_1950to1970_1972.set_index(columns)

#1973
df1_1972actual = pd.DataFrame(actual_values_array_1972)
df2_predicted_1973_1970to1988slope = pd.DataFrame(predict_concentration_change_1970to1988_1973)
final_df_1970to1988_1973 = df1_1972actual + df2_predicted_1973_1970to1988slope
predicted_1970to1988_1973 = final_df_1950to1970_1973.set_index(columns)

#1974
df1_1973actual = pd.DataFrame(actual_values_array_1973)
df2_predicted_1974_1970to1988slope = pd.DataFrame(predict_concentration_change_1970to1988_1974)
final_df_1970to1988_1974 = df1_1973actual + df2_predicted_1974_1970to1988slope
predicted_1970to1988_1974 = final_df_1950to1970_1974.set_index(columns)

#1975
df1_1974actual = pd.DataFrame(actual_values_array_1974)
df2_predicted_1975_1970to1988slope = pd.DataFrame(predict_concentration_change_1970to1988_1975)
final_df_1970to1988_1975 = df1_1974actual + df2_predicted_1975_1970to1988slope
predicted_1970to1988_1975 = final_df_1950to1970_1975.set_index(columns)

#1976
df1_1975actual = pd.DataFrame(actual_values_array_1975)
df2_predicted_1976_1970to1988slope = pd.DataFrame(predict_concentration_change_1970to1988_1976)
final_df_1970to1988_1976 = df1_1975actual + df2_predicted_1976_1970to1988slope
predicted_1970to1988_1976 = final_df_1950to1970_1976.set_index(columns)

#1977
df1_1976actual = pd.DataFrame(actual_values_array_1976)
df2_predicted_1977_1970to1988slope = pd.DataFrame(predict_concentration_change_1970to1988_1977)
final_df_1970to1988_1977 = df1_1976actual + df2_predicted_1977_1970to1988slope
predicted_1970to1988_1977 = final_df_1950to1970_1977.set_index(columns)

#1978
df1_1977actual = pd.DataFrame(actual_values_array_1977)
df2_predicted_1978_1970to1988slope = pd.DataFrame(predict_concentration_change_1970to1988_1978)
final_df_1970to1988_1978 = df1_1977actual + df2_predicted_1978_1970to1988slope
predicted_1970to1988_1978 = final_df_1950to1970_1978.set_index(columns)

#1979
df1_1978actual = pd.DataFrame(actual_values_array_1978)
df2_predicted_1979_1970to1988slope = pd.DataFrame(predict_concentration_change_1970to1988_1979)
final_df_1970to1988_1979 = df1_1978actual + df2_predicted_1979_1970to1988slope
predicted_1970to1988_1979 = final_df_1950to1970_1979.set_index(columns)

#1980
df1_1979actual = pd.DataFrame(actual_values_array_1979)
df2_predicted_1980_1970to1988slope = pd.DataFrame(predict_concentration_change_1970to1988_1980)
final_df_1970to1988_19 = df1_1979actual + df2_predicted_1980_1970to1988slope
predicted_1970to1988_1980 = final_df_1950to1970_1974.set_index(columns)



#Here I am using the base slope of 1988 to 2014 to get every predictions between 1970 through 1980
#NOTE that to get the prediction for the next year you must multiply the slope from the PREVIOUS year
#---------------------------------------------------------------------------------------------------------------------------#

#1971
df1_1970actual = pd.DataFrame(last_value_array_1970)
df2_predicted_1971_1988to2014slope = pd.DataFrame(predict_concentration_change_1988to2014_1971)
final_df_1988to2014_1971 = df1_1970actual + df2_predicted_1971_1988to2014slope
predicted_1980to2014_1971 = final_df_1988to2014_1971.set_index(columns)

#1972
df1_1971actual = pd.DataFrame(actual_values_array_1971)
df2_predicted_1972_1988to2014slope = pd.DataFrame(predict_concentration_change_1988to2014_1972)
final_df_1988to2014_1972 = df1_1971actual + df2_predicted_1972_1988to2014slope
predicted_1980to2014_1972 = final_df_1988to2014_1972.set_index(columns)

#1973
df1_1972actual = pd.DataFrame(actual_values_array_1972)
df2_predicted_1973_1988to2014slope = pd.DataFrame(predict_concentration_change_1988to2014_1973)
final_df_1988to2014_1973 = df1_1972actual + df2_predicted_1973_1988to2014slope
predicted_1980to2014_1973 = final_df_1988to2014_1973.set_index(columns)

#1974
df1_1973actual = pd.DataFrame(actual_values_array_1973)
df2_predicted_1974_1988to2014slope = pd.DataFrame(predict_concentration_change_1988to2014_1974)
final_df_1988to2014_1974 = df1_1973actual + df2_predicted_1974_1988to2014slope
predicted_1980to2014_1974 = final_df_1988to2014_1974.set_index(columns)

#1975
df1_1974actual = pd.DataFrame(actual_values_array_1974)
df2_predicted_1975_1988to2014slope = pd.DataFrame(predict_concentration_change_1988to2014_1975)
final_df_1988to2014_1975 = df1_1974actual + df2_predicted_1975_1988to2014slope
predicted_1980to2014_1975 = final_df_1988to2014_1975.set_index(columns)

#1976
df1_1975actual = pd.DataFrame(actual_values_array_1975)
df2_predicted_1976_1988to2014slope = pd.DataFrame(predict_concentration_change_1988to2014_1976)
final_df_1988to2014_1976 = df1_1975actual + df2_predicted_1976_1988to2014slope
predicted_1980to2014_1976 = final_df_1988to2014_1976.set_index(columns)

#1977
df1_1976actual = pd.DataFrame(actual_values_array_1976)
df2_predicted_1977_1988to2014slope = pd.DataFrame(predict_concentration_change_1988to2014_1977)
final_df_1988to2014_1977 = df1_1976actual + df2_predicted_1977_1988to2014slope
predicted_1980to2014_1977 = final_df_1988to2014_1977.set_index(columns)

#1978
df1_1977actual = pd.DataFrame(actual_values_array_1977)
df2_predicted_1978_1988to2014slope = pd.DataFrame(predict_concentration_change_1988to2014_1978)
final_df_1988to2014_1978 = df1_1977actual + df2_predicted_1978_1988to2014slope
predicted_1980to2014_1978 = final_df_1988to2014_1978.set_index(columns)

#1979
df1_1978actual = pd.DataFrame(actual_values_array_1978)
df2_predicted_1979_1988to2014slope = pd.DataFrame(predict_concentration_change_1988to2014_1979)
final_df_1988to2014_1979 = df1_1978actual + df2_predicted_1979_1988to2014slope
predicted_1980to2014_1979 = final_df_1988to2014_1979.set_index(columns)

#1980
df1_1979actual = pd.DataFrame(actual_values_array_1979)
df2_predicted_1980_1988to2014slope = pd.DataFrame(predict_concentration_change_1988to2014_1980)
final_df_1988to2014_1980 = df1_1979actual + df2_predicted_1980_1988to2014slope
predicted_1980to2014_1980 = final_df_1988to2014_1980.set_index(columns)

# %%
#Here we are grabbing the actual data from the year we are predicting
#---------------------------------------------------------------------------------------#

#Actual concentration amounts for 1971
actual_1971 = pd.DataFrame(mol.iloc[base_year_1970 + year_interval])
actual_1972 = pd.DataFrame(mol.iloc[base_year_1970 + year_interval_2])
actual_1973 = pd.DataFrame(mol.iloc[base_year_1970 + year_interval_3])
actual_1974 = pd.DataFrame(mol.iloc[base_year_1970 + year_interval_4])
actual_1975 = pd.DataFrame(mol.iloc[base_year_1970 + year_interval_5])
actual_1976 = pd.DataFrame(mol.iloc[base_year_1970 + year_interval_6])
actual_1977 = pd.DataFrame(mol.iloc[base_year_1970 + year_interval_7])
actual_1978 = pd.DataFrame(mol.iloc[base_year_1970 + year_interval_8])
actual_1979 = pd.DataFrame(mol.iloc[base_year_1970 + year_interval_9])
actual_1980 = pd.DataFrame(mol.iloc[base_year_1970 + year_interval_10])

# %%
#Here we are joining our predicted and actual data; renaming the columns for convenience
#---------------------------------------------------------------------------------------#

#Summary of slope of 1950to1970 for predictions for 1970 to 1971
summary_1971_1950to1970slope = actual_1971.join(predicted_1950to1970, how='outer')
clean_summary_1971_1950to1970slope = summary_1971_1950to1970slope.rename(columns={91:'Actual', 0: 'Predict'})

#Summary of slope of 1970to1988 for predictions for 1970 to 1971
summary_1971_1970to1988slope = actual_1971.join(predicted_1970to1988, how='outer')
clean_summary_1971_1970to1988slope = summary_1971_1970to1988slope.rename(columns={91:'Actual', 0: 'Predict'})

#Summary of slope of 1988to2014 for predictions for 1970 to 1971
summary_1971_1988to2014slope = actual_1971.join(predicted_1988to2014, how='outer')
clean_summary_1971_1988to2014slope = summary_1971_1988to2014slope.rename(columns={91:'Actual', 0: 'Predict'})

#Summary of slope of 2009to2014 for predictions for 1970 to 1971
summary_1971_2009to2014slope = actual_1971.join(predicted_2009to2014, how='outer')
clean_summary_1971_2009to2014slope = summary_1971_2009to2014slope.rename(columns={91:'Actual', 0: 'Predict'})

#Here I am using the base slope of 1950 to 1970 ("The Great Acceleration") to get every predictions between 1970 through 1980
#---------------------------------------------------------------------------------------------------------------------------#

#1971
summary_1971_1950to1970slope = actual_1971.join(predicted_1950to1970_1971, how='outer')
clean_summary_1971_1950to1970slope = summary_1971_1950to1970slope.rename(columns={91:'Actual', 0: 'Predict'})

#1972
summary_1972_1950to1970slope = actual_1972.join(predicted_1950to1970_1972, how='outer')
clean_summary_1972_1950to1970slope = summary_1972_1950to1970slope.rename(columns={92:'Actual', 0: 'Predict'})

#1973
summary_1973_1950to1970slope = actual_1973.join(predicted_1950to1970_1973, how='outer')
clean_summary_1973_1950to1970slope = summary_1973_1950to1970slope.rename(columns={93:'Actual', 0: 'Predict'})

#1974
summary_1974_1950to1970slope = actual_1974.join(predicted_1950to1970_1971, how='outer')
clean_summary_1974_1950to1970slope = summary_1974_1950to1970slope.rename(columns={94:'Actual', 0: 'Predict'})

#1975
summary_1975_1950to1970slope = actual_1975.join(predicted_1950to1970_1971, how='outer')
clean_summary_1975_1950to1970slope = summary_1975_1950to1970slope.rename(columns={95:'Actual', 0: 'Predict'})

#1976
summary_1976_1950to1970slope = actual_1976.join(predicted_1950to1970_1971, how='outer')
clean_summary_1976_1950to1970slope = summary_1976_1950to1970slope.rename(columns={96:'Actual', 0: 'Predict'})

#1977
summary_1977_1950to1970slope = actual_1977.join(predicted_1950to1970_1971, how='outer')
clean_summary_1977_1950to1970slope = summary_1977_1950to1970slope.rename(columns={97:'Actual', 0: 'Predict'})

#1978
summary_1978_1950to1970slope = actual_1978.join(predicted_1950to1970_1971, how='outer')
clean_summary_1978_1950to1970slope = summary_1978_1950to1970slope.rename(columns={98:'Actual', 0: 'Predict'})

#1979
summary_1979_1950to1970slope = actual_1979.join(predicted_1950to1970_1971, how='outer')
clean_summary_1979_1950to1970slope = summary_1979_1950to1970slope.rename(columns={99:'Actual', 0: 'Predict'})

#1980
summary_1980_1950to1970slope = actual_1980.join(predicted_1950to1970_1971, how='outer')
clean_summary_1980_1950to1970slope = summary_1980_1950to1970slope.rename(columns={100:'Actual', 0: 'Predict'})

#Here I am using the base slope of 1970 to 1988 to get every predictions between 1970 through 1980
#---------------------------------------------------------------------------------------------------------------------------#

#1971
summary_1971_1970to1988slope = actual_1971.join(predicted_1970to1988_1971, how='outer')
clean_summary_1971_1970to1988slope = summary_1971_1970to1988slope.rename(columns={91:'Actual', 0: 'Predict'})

#1972
summary_1972_1970to1988slope = actual_1972.join(predicted_1970to1988_1972, how='outer')
clean_summary_1972_1970to1988slope = summary_1972_1970to1988slope.rename(columns={92:'Actual', 0: 'Predict'})

#1973
summary_1973_1970to1988slope = actual_1973.join(predicted_1970to1988_1973, how='outer')
clean_summary_1973_1970to1988slope = summary_1973_1970to1988slope.rename(columns={93:'Actual', 0: 'Predict'})

#1974
summary_1974_1970to1988slope = actual_1974.join(predicted_1970to1988_1974, how='outer')
clean_summary_1974_1970to1988slope = summary_1974_1970to1988slope.rename(columns={94:'Actual', 0: 'Predict'})

#1975
summary_1975_1970to1988slope = actual_1975.join(predicted_1970to1988_1975, how='outer')
clean_summary_1975_1970to1988slope = summary_1975_1970to1988slope.rename(columns={95:'Actual', 0: 'Predict'})

#1976
summary_1976_1970to1988slope = actual_1976.join(predicted_1970to1988_1976, how='outer')
clean_summary_1976_1970to1988slope = summary_1976_1970to1988slope.rename(columns={96:'Actual', 0: 'Predict'})

#1977
summary_1977_1970to1988slope = actual_1977.join(predicted_1970to1988_1977, how='outer')
clean_summary_1977_1970to1988slope = summary_1977_1970to1988slope.rename(columns={97:'Actual', 0: 'Predict'})

#1978
summary_1978_1970to1988slope = actual_1978.join(predicted_1970to1988_1978, how='outer')
clean_summary_1978_1970to1988slope = summary_1978_1970to1988slope.rename(columns={98:'Actual', 0: 'Predict'})

#1979
summary_1979_1970to1988slope = actual_1979.join(predicted_1970to1988_1979, how='outer')
clean_summary_1979_1970to1988slope = summary_1979_1970to1988slope.rename(columns={99:'Actual', 0: 'Predict'})

#1980
summary_1980_1970to1988slope = actual_1980.join(predicted_1970to1988_1980, how='outer')
clean_summary_1980_1970to1988slope = summary_1980_1970to1988slope.rename(columns={100:'Actual', 0: 'Predict'})



#Here I am using the base slope of 1980 to 2014 to get every predictions between 1970 through 1980
#---------------------------------------------------------------------------------------------------------------------------#

#1971
summary_1971_1988to2014slope = actual_1971.join(predicted_1980to2014_1971, how='outer')
clean_summary_1971_1988to2014slope = summary_1971_1988to2014slope.rename(columns={91:'Actual', 0: 'Predict'})

#1972
summary_1972_1988to2014slope = actual_1972.join(predicted_1980to2014_1972, how='outer')
clean_summary_1972_1988to2014slope = summary_1972_1988to2014slope.rename(columns={92:'Actual', 0: 'Predict'})

#1973
summary_1973_1988to2014slope = actual_1973.join(predicted_1980to2014_1973, how='outer')
clean_summary_1973_1988to2014slope = summary_1973_1988to2014slope.rename(columns={93:'Actual', 0: 'Predict'})

#1974
summary_1974_1988to2014slope = actual_1974.join(predicted_1980to2014_1974, how='outer')
clean_summary_1974_1988to2014slope = summary_1974_1988to2014slope.rename(columns={94:'Actual', 0: 'Predict'})

#1975
summary_1975_1988to2014slope = actual_1975.join(predicted_1980to2014_1975, how='outer')
clean_summary_1975_1988to2014slope = summary_1975_1988to2014slope.rename(columns={95:'Actual', 0: 'Predict'})

#1976
summary_1976_1988to2014slope = actual_1976.join(predicted_1980to2014_1976, how='outer')
clean_summary_1976_1988to2014slope = summary_1976_1988to2014slope.rename(columns={96:'Actual', 0: 'Predict'})

#1977
summary_1977_1988to2014slope = actual_1977.join(predicted_1980to2014_1977, how='outer')
clean_summary_1977_1988to2014slope = summary_1977_1988to2014slope.rename(columns={97:'Actual', 0: 'Predict'})

#1978
summary_1978_1988to2014slope = actual_1978.join(predicted_1980to2014_1978, how='outer')
clean_summary_1978_1988to2014slope = summary_1978_1988to2014slope.rename(columns={98:'Actual', 0: 'Predict'})

#1979
summary_1979_1988to2014slope = actual_1979.join(predicted_1980to2014_1979, how='outer')
clean_summary_1979_1988to2014slope = summary_1979_1988to2014slope.rename(columns={99:'Actual', 0: 'Predict'})

#1980
summary_1980_1988to2014slope = actual_1980.join(predicted_1980to2014_1980, how='outer')
clean_summary_1980_1988to2014slope = summary_1980_1988to2014slope.rename(columns={100:'Actual', 0: 'Predict'})

# %%
#Here we are doing our calculation to get our %difference in actual and predicted results
#-------------------------------------------------------------------------------------------------#

#1971 cleaning USING 1950to1970 slope
clean_summary_1971_1950to1970slope['Pct Difference'] = ((clean_summary_1971_1950to1970slope['Actual'] - clean_summary_1971_1950to1970slope['Predict'])/clean_summary_1971_1950to1970slope['Actual']) * 100

#1971 cleaning USING 1970to1988 slope
clean_summary_1971_1970to1988slope['Pct Difference'] = ((clean_summary_1971_1970to1988slope['Actual'] - clean_summary_1971_1970to1988slope['Predict'])/clean_summary_1971_1970to1988slope['Actual']) * 100

#1971 cleaning USING 1988to2014 slope
clean_summary_1971_1988to2014slope['Pct Difference'] = ((clean_summary_1971_1988to2014slope['Actual'] - clean_summary_1971_1988to2014slope['Predict'])/clean_summary_1971_1988to2014slope['Actual']) * 100

#1971 cleaning USING 2009to2014 slope
clean_summary_1971_2009to2014slope['Pct Difference'] = ((clean_summary_1971_2009to2014slope['Actual'] - clean_summary_1971_2009to2014slope['Predict'])/clean_summary_1971_2009to2014slope['Actual']) * 100




#Here I am using the base slope of 1950 to 1970 ("The Great Acceleration") to get every predictions between 1970 through 1980
#---------------------------------------------------------------------------------------------------------------------------#

#1971
clean_summary_1971_1950to1970slope['Pct Difference'] = ((clean_summary_1971_1950to1970slope['Actual'] - clean_summary_1971_1950to1970slope['Predict'])/clean_summary_1971_1950to1970slope['Actual']) * 100

#1972
clean_summary_1972_1950to1970slope['Pct Difference'] = ((clean_summary_1972_1950to1970slope['Actual'] - clean_summary_1972_1950to1970slope['Predict'])/clean_summary_1972_1950to1970slope['Actual']) * 100

#1973
clean_summary_1973_1950to1970slope['Pct Difference'] = ((clean_summary_1973_1950to1970slope['Actual'] - clean_summary_1973_1950to1970slope['Predict'])/clean_summary_1973_1950to1970slope['Actual']) * 100

#1974
clean_summary_1974_1950to1970slope['Pct Difference'] = ((clean_summary_1974_1950to1970slope['Actual'] - clean_summary_1974_1950to1970slope['Predict'])/clean_summary_1974_1950to1970slope['Actual']) * 100

#1975
clean_summary_1975_1950to1970slope['Pct Difference'] = ((clean_summary_1975_1950to1970slope['Actual'] - clean_summary_1975_1950to1970slope['Predict'])/clean_summary_1975_1950to1970slope['Actual']) * 100

#1976
clean_summary_1976_1950to1970slope['Pct Difference'] = ((clean_summary_1976_1950to1970slope['Actual'] - clean_summary_1976_1950to1970slope['Predict'])/clean_summary_1976_1950to1970slope['Actual']) * 100

#1977
clean_summary_1977_1950to1970slope['Pct Difference'] = ((clean_summary_1977_1950to1970slope['Actual'] - clean_summary_1977_1950to1970slope['Predict'])/clean_summary_1977_1950to1970slope['Actual']) * 100

#1978
clean_summary_1978_1950to1970slope['Pct Difference'] = ((clean_summary_1978_1950to1970slope['Actual'] - clean_summary_1978_1950to1970slope['Predict'])/clean_summary_1978_1950to1970slope['Actual']) * 100

#1979
clean_summary_1979_1950to1970slope['Pct Difference'] = ((clean_summary_1979_1950to1970slope['Actual'] - clean_summary_1979_1950to1970slope['Predict'])/clean_summary_1979_1950to1970slope['Actual']) * 100

#1980
clean_summary_1980_1950to1970slope['Pct Difference'] = ((clean_summary_1980_1950to1970slope['Actual'] - clean_summary_1980_1950to1970slope['Predict'])/clean_summary_1980_1950to1970slope['Actual']) * 100





#Here I am using the base slope of 1970 to 1988 to get every predictions between 1970 through 1980
#---------------------------------------------------------------------------------------------------------------------------#

#1971
clean_summary_1971_1970to1988slope['Pct Difference'] = ((clean_summary_1971_1970to1988slope['Actual'] - clean_summary_1971_1970to1988slope['Predict'])/clean_summary_1971_1970to1988slope['Actual']) * 100

#1972
clean_summary_1972_1970to1988slope['Pct Difference'] = ((clean_summary_1972_1970to1988slope['Actual'] - clean_summary_1972_1970to1988slope['Predict'])/clean_summary_1972_1970to1988slope['Actual']) * 100

#1973
clean_summary_1973_1970to1988slope['Pct Difference'] = ((clean_summary_1973_1970to1988slope['Actual'] - clean_summary_1973_1970to1988slope['Predict'])/clean_summary_1973_1970to1988slope['Actual']) * 100

#1974
clean_summary_1974_1970to1988slope['Pct Difference'] = ((clean_summary_1974_1970to1988slope['Actual'] - clean_summary_1974_1970to1988slope['Predict'])/clean_summary_1974_1970to1988slope['Actual']) * 100

#1975
clean_summary_1975_1970to1988slope['Pct Difference'] = ((clean_summary_1975_1970to1988slope['Actual'] - clean_summary_1975_1970to1988slope['Predict'])/clean_summary_1975_1970to1988slope['Actual']) * 100

#1976
clean_summary_1976_1970to1988slope['Pct Difference'] = ((clean_summary_1976_1970to1988slope['Actual'] - clean_summary_1976_1970to1988slope['Predict'])/clean_summary_1976_1970to1988slope['Actual']) * 100

#1977
clean_summary_1977_1970to1988slope['Pct Difference'] = ((clean_summary_1977_1970to1988slope['Actual'] - clean_summary_1977_1970to1988slope['Predict'])/clean_summary_1977_1970to1988slope['Actual']) * 100

#1978
clean_summary_1978_1970to1988slope['Pct Difference'] = ((clean_summary_1978_1970to1988slope['Actual'] - clean_summary_1978_1970to1988slope['Predict'])/clean_summary_1978_1970to1988slope['Actual']) * 100

#1979
clean_summary_1979_1970to1988slope['Pct Difference'] = ((clean_summary_1979_1970to1988slope['Actual'] - clean_summary_1979_1970to1988slope['Predict'])/clean_summary_1979_1970to1988slope['Actual']) * 100

#1980
clean_summary_1980_1970to1988slope['Pct Difference'] = ((clean_summary_1980_1970to1988slope['Actual'] - clean_summary_1980_1970to1988slope['Predict'])/clean_summary_1980_1970to1988slope['Actual']) * 100






#Here I am using the base slope of 1988 to 2014 to get every predictions between 1970 through 1980
#---------------------------------------------------------------------------------------------------------------------------#

#1971
clean_summary_1971_1988to2014slope['Pct Difference'] = ((clean_summary_1971_1988to2014slope['Actual'] - clean_summary_1971_1988to2014slope['Predict'])/clean_summary_1971_1988to2014slope['Actual']) * 100

#1972
clean_summary_1972_1988to2014slope['Pct Difference'] = ((clean_summary_1972_1988to2014slope['Actual'] - clean_summary_1972_1988to2014slope['Predict'])/clean_summary_1972_1988to2014slope['Actual']) * 100

#1973
clean_summary_1973_1988to2014slope['Pct Difference'] = ((clean_summary_1973_1988to2014slope['Actual'] - clean_summary_1973_1988to2014slope['Predict'])/clean_summary_1973_1988to2014slope['Actual']) * 100

#1974
clean_summary_1974_1988to2014slope['Pct Difference'] = ((clean_summary_1974_1988to2014slope['Actual'] - clean_summary_1974_1988to2014slope['Predict'])/clean_summary_1974_1988to2014slope['Actual']) * 100

#1975
clean_summary_1975_1988to2014slope['Pct Difference'] = ((clean_summary_1975_1988to2014slope['Actual'] - clean_summary_1975_1988to2014slope['Predict'])/clean_summary_1975_1988to2014slope['Actual']) * 100

#1976
clean_summary_1976_1988to2014slope['Pct Difference'] = ((clean_summary_1976_1988to2014slope['Actual'] - clean_summary_1976_1988to2014slope['Predict'])/clean_summary_1976_1988to2014slope['Actual']) * 100

#1977
clean_summary_1977_1988to2014slope['Pct Difference'] = ((clean_summary_1977_1988to2014slope['Actual'] - clean_summary_1977_1988to2014slope['Predict'])/clean_summary_1977_1988to2014slope['Actual']) * 100

#1978
clean_summary_1978_1988to2014slope['Pct Difference'] = ((clean_summary_1978_1988to2014slope['Actual'] - clean_summary_1978_1988to2014slope['Predict'])/clean_summary_1978_1988to2014slope['Actual']) * 100

#1979
clean_summary_1979_1988to2014slope['Pct Difference'] = ((clean_summary_1979_1988to2014slope['Actual'] - clean_summary_1979_1988to2014slope['Predict'])/clean_summary_1979_1988to2014slope['Actual']) * 100

#1980
clean_summary_1980_1988to2014slope['Pct Difference'] = ((clean_summary_1980_1988to2014slope['Actual'] - clean_summary_1980_1988to2014slope['Predict'])/clean_summary_1980_1988to2014slope['Actual']) * 100

# %%
year_1971 = 1971
year_1972 = 1972
year_1973 = 1973
year_1974 = 1974
year_1975 = 1975
year_1976 = 1976
year_1977 = 1977
year_1978 = 1978
year_1979 = 1979
year_1980 = 1980

clean_summary_1971_1950to1970slope["Year"] = year_1971
clean_summary_1972_1950to1970slope["Year"] = year_1972
clean_summary_1973_1950to1970slope["Year"] = year_1973
clean_summary_1974_1950to1970slope["Year"] = year_1974
clean_summary_1975_1950to1970slope["Year"] = year_1975
clean_summary_1976_1950to1970slope["Year"] = year_1976
clean_summary_1977_1950to1970slope["Year"] = year_1977
clean_summary_1978_1950to1970slope["Year"] = year_1978
clean_summary_1979_1950to1970slope["Year"] = year_1979
clean_summary_1980_1950to1970slope["Year"] = year_1980

# %%
merge_test1 = pd.merge(clean_summary_1971_1950to1970slope, clean_summary_1972_1950to1970slope, left_index=True, right_index=True)
merge_test2 = pd.merge(merge_test1, clean_summary_1973_1950to1970slope, left_index=True, right_index=True)
merge_test2 = merge_test2.rename(columns={'Actual_x':'1971Actual', 'Predict_x': '1971Predict', 'Actual_y':'1972Actual',"Predict_y":"1972Predict","Actual":"1973Actual","Predict":"1973Predict"})
merge_test3 = pd.merge(merge_test2, clean_summary_1974_1950to1970slope, left_index=True, right_index=True)
merge_test3 = merge_test3.rename(columns={"Actual":"1974Actual","Predict":"1974Predict"})
#merge_test3 = df.drop(["Pct Difference_x", "Year_x", "Year_y", "Pct Difference_x",], index=None, columns=None, level=None, inplace=False, errors='raise')
#merge_test3 = merge_test3.drop(['Pct Difference_x', 'Year_x', 'Year_y','Pct Difference_y'], axis=1)
merge_test4 = pd.merge(merge_test3, clean_summary_1975_1950to1970slope, left_index=True, right_index=True)
merge_test4 = merge_test4.rename(columns={"Actual":"1975Actual","Predict":"1975Predict"})
merge_test4 = merge_test4.drop(['Pct Difference', 'Year'], axis=1)
merge_test5 = pd.merge(merge_test4, clean_summary_1976_1950to1970slope, left_index=True, right_index=True)
merge_test5 = merge_test5.rename(columns={"Actual":"1976Actual","Predict":"1976Predict"})
merge_test5 = merge_test5.drop(['Pct Difference', 'Year'], axis=1)
merge_test6 = pd.merge(merge_test5, clean_summary_1977_1950to1970slope, left_index=True, right_index=True)
merge_test6 = merge_test6.rename(columns={"Actual":"1977Actual","Predict":"1977Predict"})
merge_test6 = merge_test6.drop(['Pct Difference', 'Year'], axis=1)
merge_test7 = pd.merge(merge_test6, clean_summary_1978_1950to1970slope, left_index=True, right_index=True)
merge_test7 = merge_test7.rename(columns={"Actual":"1978Actual","Predict":"1978Predict"})
merge_test7 = merge_test7.drop(['Pct Difference', 'Year'], axis=1)
merge_test8 = pd.merge(merge_test7, clean_summary_1979_1950to1970slope, left_index=True, right_index=True)
merge_test8 = merge_test8.rename(columns={"Actual":"1979Actual","Predict":"1979Predict"})
merge_test8 = merge_test8.drop(['Pct Difference', 'Year'], axis=1)
merge_final = pd.merge(merge_test8, clean_summary_1980_1950to1970slope, left_index=True, right_index=True)
merge_final = merge_final.rename(columns={"Actual":"1980Actual","Predict":"1980Predict"})
merge_final = merge_final.drop(['Pct Difference', 'Year'], axis=1)
merge_final_no1000 = merge_final.drop(['CH4','CH3Cl'])
merge_final_no200 = merge_final.drop(['CH4','CH3Cl','CO2','N20'])
merge_final_no50 = merge_final_no200.drop(['CFC12','CFC11','CCl4','CF4','CH3CCl3','HCFC22'])

# %%
merge_test1_1970to1988 = pd.merge(clean_summary_1971_1970to1988slope, clean_summary_1972_1970to1988slope, left_index=True, right_index=True)
merge_test2_1970to1988 = pd.merge(merge_test1_1970to1988, clean_summary_1973_1970to1988slope, left_index=True, right_index=True)
merge_test2_1970to1988 = merge_test2.rename(columns={'Actual_x':'1971Actual', 'Predict_x': '1971Predict', 'Actual_y':'1972Actual',"Predict_y":"1972Predict","Actual":"1973Actual","Predict":"1973Predict"})
merge_test3_1970to1988 = pd.merge(merge_test2_1970to1988, clean_summary_1974_1970to1988slope, left_index=True, right_index=True)
merge_test3_1970to1988 = merge_test3_1970to1988.rename(columns={"Actual":"1974Actual","Predict":"1974Predict"})
#merge_test3 = df.drop(["Pct Difference_x", "Year_x", "Year_y", "Pct Difference_x",], index=None, columns=None, level=None, inplace=False, errors='raise')
merge_test3_1970to1988 = merge_test3_1970to1988.drop(['Pct Difference_x','Pct Difference_y'], axis=1)
merge_test4_1970to1988 = pd.merge(merge_test3_1970to1988, clean_summary_1975_1970to1988slope, left_index=True, right_index=True)
merge_test4_1970to1988 = merge_test4_1970to1988.rename(columns={"Actual":"1975Actual","Predict":"1975Predict"})
merge_test4_1970to1988 = merge_test4_1970to1988.drop(['Pct Difference'], axis=1)
merge_test5_1970to1988 = pd.merge(merge_test4_1970to1988, clean_summary_1976_1970to1988slope, left_index=True, right_index=True)
merge_test5_1970to1988 = merge_test5_1970to1988.rename(columns={"Actual":"1976Actual","Predict":"1976Predict"})
merge_test5_1970to1988 = merge_test5_1970to1988.drop(['Pct Difference'], axis=1)
merge_test6_1970to1988 = pd.merge(merge_test5_1970to1988, clean_summary_1977_1970to1988slope, left_index=True, right_index=True)
merge_test6_1970to1988 = merge_test6_1970to1988.rename(columns={"Actual":"1977Actual","Predict":"1977Predict"})
merge_test6_1970to1988 = merge_test6_1970to1988.drop(['Pct Difference'], axis=1)
merge_test7_1970to1988 = pd.merge(merge_test6_1970to1988, clean_summary_1978_1970to1988slope, left_index=True, right_index=True)
merge_test7_1970to1988 = merge_test7_1970to1988.rename(columns={"Actual":"1978Actual","Predict":"1978Predict"})
merge_test7_1970to1988 = merge_test7_1970to1988.drop(['Pct Difference'], axis=1)
merge_test8_1970to1988 = pd.merge(merge_test7_1970to1988, clean_summary_1979_1970to1988slope, left_index=True, right_index=True)
merge_test8_1970to1988 = merge_test8_1970to1988.rename(columns={"Actual":"1979Actual","Predict":"1979Predict"})
merge_test8_1970to1988 = merge_test8_1970to1988.drop(['Pct Difference'], axis=1)
merge_final_1970to1988 = pd.merge(merge_test8_1970to1988, clean_summary_1980_1970to1988slope, left_index=True, right_index=True)
merge_final_1970to1988 = merge_final_1970to1988.rename(columns={"Actual":"1980Actual","Predict":"1980Predict"})
merge_final_1970to1988 = merge_final_1970to1988.drop(['Pct Difference'], axis=1)
merge_final_no1000_1970to1988 = merge_final_1970to1988.drop(['CH4','CH3Cl'])
merge_final_no200_1970to1988 = merge_final_1970to1988.drop(['CH4','CH3Cl','CO2','N20'])
merge_final_no50_1970to1988 = merge_final_no200_1970to1988.drop(['CFC12','CFC11','CCl4','CF4','CH3CCl3','HCFC22'])

# %%
merge_test1_1980to2014 = pd.merge(clean_summary_1971_1988to2014slope, clean_summary_1972_1988to2014slope, left_index=True, right_index=True)
merge_test2_1980to2014 = pd.merge(merge_test1_1980to2014, clean_summary_1973_1988to2014slope, left_index=True, right_index=True)
merge_test2_1980to2014 = merge_test2_1980to2014.rename(columns={'Actual_x':'1971Actual', 'Predict_x': '1971Predict', 'Actual_y':'1972Actual',"Predict_y":"1972Predict","Actual":"1973Actual","Predict":"1973Predict"})
merge_test3_1980to2014 = pd.merge(merge_test2_1980to2014, clean_summary_1974_1988to2014slope, left_index=True, right_index=True)
merge_test3_1980to2014 = merge_test3_1980to2014.rename(columns={"Actual":"1974Actual","Predict":"1974Predict"})
#merge_test3 = df.drop(["Pct Difference_x", "Year_x", "Year_y", "Pct Difference_x",], index=None, columns=None, level=None, inplace=False, errors='raise')
merge_test3_1980to2014 = merge_test3_1980to2014.drop(['Pct Difference_x','Pct Difference_y'], axis=1)
merge_test4_1980to2014 = pd.merge(merge_test3_1980to2014, clean_summary_1975_1988to2014slope, left_index=True, right_index=True)
merge_test4_1980to2014 = merge_test4_1980to2014.rename(columns={"Actual":"1975Actual","Predict":"1975Predict"})
merge_test4_1980to2014 = merge_test4_1980to2014.drop(['Pct Difference'], axis=1)
merge_test5_1980to2014 = pd.merge(merge_test4_1980to2014, clean_summary_1976_1988to2014slope, left_index=True, right_index=True)
merge_test5_1980to2014 = merge_test5_1980to2014.rename(columns={"Actual":"1976Actual","Predict":"1976Predict"})
merge_test5_1980to2014 = merge_test5_1980to2014.drop(['Pct Difference'], axis=1)
merge_test6_1980to2014 = pd.merge(merge_test5_1980to2014, clean_summary_1977_1988to2014slope, left_index=True, right_index=True)
merge_test6_1980to2014 = merge_test6_1980to2014.rename(columns={"Actual":"1977Actual","Predict":"1977Predict"})
merge_test6_1980to2014 = merge_test6_1980to2014.drop(['Pct Difference'], axis=1)
merge_test7_1980to2014 = pd.merge(merge_test6_1980to2014, clean_summary_1978_1988to2014slope, left_index=True, right_index=True)
merge_test7_1980to2014 = merge_test7_1980to2014.rename(columns={"Actual":"1978Actual","Predict":"1978Predict"})
merge_test7_1980to2014 = merge_test7_1980to2014.drop(['Pct Difference'], axis=1)
merge_test8_1980to2014 = pd.merge(merge_test7_1980to2014, clean_summary_1979_1988to2014slope, left_index=True, right_index=True)
merge_test8_1980to2014 = merge_test8_1980to2014.rename(columns={"Actual":"1979Actual","Predict":"1979Predict"})
merge_test8_1980to2014 = merge_test8_1980to2014.drop(['Pct Difference'], axis=1)
merge_final_1980to2014 = pd.merge(merge_test8_1980to2014, clean_summary_1980_1988to2014slope, left_index=True, right_index=True)
merge_final_1980to2014 = merge_final_1980to2014.rename(columns={"Actual":"1980Actual","Predict":"1980Predict"})
merge_final_1980to2014 = merge_final_1980to2014.drop(['Pct Difference'], axis=1)
merge_final_no1000_1980to2014 = merge_final_1980to2014.drop(['CH4','CH3Cl'])
merge_final_no200_1980to2014 = merge_final_1980to2014.drop(['CH4','CH3Cl','CO2','N20'])
merge_final_no50_1980to2014 = merge_final_no200_1980to2014.drop(['CFC12','CFC11','CCl4','CF4','CH3CCl3','HCFC22'])

# %%
import matplotlib.pyplot as plt

plt.scatter(merge_final_no50['1971Actual'], merge_final_no50['1972Actual'], s=300, color = ['gold'], edgecolor = 'black', alpha = .75)
plt.scatter(merge_final_no50['1973Actual'], merge_final_no50['1974Actual'], s=300, color = ['gold'], edgecolor = 'black', alpha = .75)
plt.scatter(merge_final_no50['1975Actual'], merge_final_no50['1976Actual'], s=300, color = ['gold'], edgecolor = 'black', alpha = .75)
plt.scatter(merge_final_no50['1971Predict'], merge_final_no50['1972Predict'], s=300, color = ['red'], edgecolor = 'black', alpha = .75)
plt.scatter(merge_final_no50['1973Predict'], merge_final_no50['1974Predict'], s=300, color = ['red'], edgecolor = 'black', alpha = .75)
plt.scatter(merge_final_no50['1975Predict'], merge_final_no50['1976Predict'], s=300, color = ['red'], edgecolor = 'black', alpha = .75)
plt.grid()
plt.savefig('1950to1970slope.png')

# %%
plt.scatter(merge_final_no50_1970to1988['1971Actual'], merge_final_no50_1970to1988['1972Actual'], s=300, color = ['gold'], edgecolor = 'black', alpha = .75)
plt.scatter(merge_final_no50_1970to1988['1973Actual'], merge_final_no50_1970to1988['1974Actual'], s=300, color = ['gold'], edgecolor = 'black', alpha = .75)
plt.scatter(merge_final_no50_1970to1988['1975Actual'], merge_final_no50_1970to1988['1976Actual'], s=300, color = ['gold'], edgecolor = 'black', alpha = .75)
plt.scatter(merge_final_no50_1970to1988['1971Predict'], merge_final_no50_1970to1988['1972Predict'], s=300, color = ['red'], edgecolor = 'black', alpha = .75)
plt.scatter(merge_final_no50_1970to1988['1973Predict'], merge_final_no50_1970to1988['1974Predict'], s=300, color = ['red'], edgecolor = 'black', alpha = .75)
plt.scatter(merge_final_no50_1970to1988['1975Predict'], merge_final_no50_1970to1988['1976Predict'], s=300, color = ['red'], edgecolor = 'black', alpha = .75)
plt.grid()
plt.savefig('1970to1988slope.png')

# %%
plt.scatter(merge_final_no50_1980to2014['1971Actual'], merge_final_no50_1980to2014['1972Actual'], s=300, color = ['gold'], edgecolor = 'black', alpha = .75)
plt.scatter(merge_final_no50_1980to2014['1973Actual'], merge_final_no50_1980to2014['1974Actual'], s=300, color = ['gold'], edgecolor = 'black', alpha = .75)
plt.scatter(merge_final_no50_1980to2014['1975Actual'], merge_final_no50_1980to2014['1976Actual'], s=300, color = ['gold'], edgecolor = 'black', alpha = .75)
plt.scatter(merge_final_no50_1980to2014['1971Predict'], merge_final_no50_1980to2014['1972Predict'], s=300, color = ['red'], edgecolor = 'black', alpha = .75)
plt.scatter(merge_final_no50_1980to2014['1973Predict'], merge_final_no50_1980to2014['1974Predict'], s=300, color = ['red'], edgecolor = 'black', alpha = .75)
plt.scatter(merge_final_no50_1980to2014['1975Predict'], merge_final_no50_1980to2014['1976Predict'], s=300, color = ['red'], edgecolor = 'black', alpha = .75)
plt.grid()
plt.savefig('1988to2014slope.png')

# %%
plt.scatter(merge_final_no50['1977Actual'], merge_final_no50['1978Actual'], s=300, color = ['gold'], edgecolor = 'black', alpha = .75)
plt.scatter(merge_final_no50['1979Actual'], merge_final_no50['1980Actual'], s=300, color = ['gold'], edgecolor = 'black', alpha = .75)
plt.scatter(merge_final_no50['1977Predict'], merge_final_no50['1978Predict'], s=300, color = ['red'], edgecolor = 'black', alpha = .75)
plt.scatter(merge_final_no50['1979Predict'], merge_final_no50['1980Predict'], s=300, color = ['red'], edgecolor = 'black', alpha = .75)
plt.grid()

# %%
#clean_summary_1971_1950to1970slope
#clean_summary_1971_1970to1988slope
#clean_summary_1971_1988to2014slope
#clean_summary_1971_2009to2014slope
#clean_summary_1980_1950to1970slope

# %%
#USE TO QUERY DATAFRAMES, IF WE WANT TO SELECT CERTAIN DATA THAT MEET A CRITERIA
testing = clean_summary_1971_1950to1970slope.query('1 <= Predict <= 10')

# %%
#INCOMPLETE--------------------ADDITIONAL SCATTER PLOT CODE------------------
actual_values_in_1971_1970to1988slope = []
predicted_values_in_1971_1970to1988slope = []

for field, real_values in testing["Actual"].items():
    actual_values_in_1971_1970to1988slope.append(real_values)
        
for field, predicted_values in testing["Predict"].items():
    predicted_values_in_1971_1970to1988slope.append(predicted_values)

# %%
#INCOMPLETE ---------------SCATTER PLOT CODE 2-----------------
import numpy as np
import matplotlib.pyplot as plt
import itertools
import operator
from functools import reduce

# Create data
g1 = actual_values_in_1971_1970to1988slope
g2 = predicted_values_in_1971_1970to1988slope
data = (g1, g2)
x = g1
y= g2
colors = ("red", "green")
groups = ("Actual", "Predicted")

# Create plot
fig = plt.figure()
ax = plt.axes(facecolor='#E6E6E6')

plt.title('Matplot scatter plot')
plt.legend(loc=2)
plt.show()
plt.scatter(x[0, :], y[1, :], c=reduce(operator.add, Y), s=40, cmap=plt.cm.Spectral)
# Out:
# No handles with labels found to put in legend.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-86-315a1e3309bf> in <module>
#      22 plt.legend(loc=2)
#      23 plt.show()
# ---> 24 plt.scatter(x[0, :], y[1, :], c=reduce(operator.add, Y), s=40, cmap=plt.cm.Spectral)
#
# TypeError: list indices must be integers or slices, not tuple

# %%
#INCOMPLETE --------------------SCATTER PLOT CODE-------------------
#DISCUSS We need to go through iterations of year for chemicals we have deemed important from ML
#Gather yearly predicted data to plot against temperature
plt.scatter(testing['Actual'], s=50, color = ['gold'], edgecolor = 'black', alpha = .75)

# %%
plt.scatter(master_DB['3Cone'], master_DB['Shuttle'], s=master_DB['ProBowl Appearances']*100, color = ['gold'], edgecolor = 'black', alpha = .75)
